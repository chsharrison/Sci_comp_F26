# %% [markdown]
# Maya Maes-Johnson
# 08/26/2026

# %% [markdown]
# # Lecture 1.2

# %% [markdown]
# Wed Aug 24th, 2026
#
# All labs are due Sunday at midnight
#
# Lecture Agenda:
# * debriefing on first class and homework, how's it going?
# * logistics of github, downloading this Lab 1.2 notebook
# * commenting and markup in notebooks
# * workflow for the class

# %% [markdown]
# In general, we will do warmup exercises and lab exercises in a jupyter notebook. For most classes, you will download the notebook from github, open it on your local computer, and then upload your completed work back on github in your folder. Then in the assignment tab in Moodle, submit a url link to the completed lab, along with a screenshot of your completed score for the chapter(s) assigned in datacamp.

# %%
# here is an example of code commenting. The # symbol means everything on this line will be ignored

# %% [markdown]
# Here is an example of markdown text. Because this cell is in markdown mode it will also be ignored by the python shell

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# You created a github account and sent Dr. Harrison your account name in Lab 1.1 to be added to the class github.
#
# Now in our class github site, create a folder for yourself where you will submit your jupyter notebooks. The easiest way to do this is to create a new file that is a placeholder document in the new folder. You can delete it later.

# %% [markdown]
# ## Warmup exercises

# %% [markdown]
# As you are doing these exercises, get familiar with jupyter notebook commands
# https://towardsdatascience.com/jypyter-notebook-shortcuts-bf0101a98330
#
# and markdown text https://medium.com/@ingeh/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed
#
# These exercises are based on what you have learned previously. Feel free to go look at what you did in datacamp to figure out how to answer them.

# %% [markdown]
# **W.1** Define and assign values to three variables of the three types we learned about Monday: integer, floating point, string and boolian.
#
# Note you can add more cells below by pressing the + button above or typing [esc] to command mode, then [b] to enter a cell below, or [a] to enter a cell above. See the link above for more commands

# %%
integer_example = 4
floating_point_example = 4.5
boolean_example = True

# %% [markdown]
# **W.2** Print out the value and check the type of each variable

# %%
print(integer_example)
print(floating_point_example)
print(boolean_example)
# Out:
# 4
# 4.5
# True

# %% [markdown]
# **W.3** Create a new variable that saves the value of the float variable as a string. Print it out

# %%
str_float = str(floating_point_example)
print(str_float)
# Out:
# 4.5

# %% [markdown]
# **W.4** Using multiplication of a variable, print out the text "Bueno Bueno Bueno Bueno Bueno" (Shoutout to Monsieur Periné https://youtu.be/JGL-eQAAxGs see 10:45)

# %%
print("bueno "*5)
# Out:
# bueno bueno bueno bueno bueno

# %% [markdown]
# **W.5** Do the same thing using addtion

# %%
print("bueno" + " " + "bueno" + " " + "bueno" + " " + "bueno" + " " + "bueno")
# Out:
# bueno bueno bueno bueno bueno

# %% [markdown]
# **W.6** If you add an int and a float, what is the resulting variable type? Demonstrate

# %% [markdown]
# <span style="color:red"> The resulting variable type will be a floating point.</span>

# %%
print(integer_example + floating_point_example)
# Out:
# 8.5

# %% [markdown]
# **W.7** Can you convert a Boolian to an interger type variable? If so, what is the resulting value? What happens if you convert a float to an int?

# %% [markdown]
# <span style="color:red"> A Boolian can be converted to an integer. It will be a 1 for 'True' or 0 for 'False.' A floating point converted to an integer will be the floating point rounded down.</span>

# %%
bool_to_int = int(boolean_example)
print(bool_to_int)
float_to_int = int(floating_point_example)
print(float_to_int)
# Out:
# 1
# 4

# %% [markdown]
# # Lab 1.2

# %% [markdown]
# ## Lab Exercises

# %% [markdown]
# **E.1** Complete Ch 2 of Introduction to Python in datacamp.

# %% [markdown]
# **E.2** Below you will spend time practicing what you have learned in Ch 2. Use a combination of code, code commenting, and markdown text to take notes. Make sure you investigate how python syntax works and understand what you are doing, and what went wrong if you have any issues. You can refer to this document later if you need to review, so give future you lots of commenting to be helpful.

# %% [markdown]
# **E.2.1** Let's work on lists, indexing and printing out elements of lists.
#
# We are going to calculate the BMI of five family members (or friends/colleaues if you have a small family, or famous people/politicians/atheletes if you really don't like talking to people, they just have to be adults and you need their data). Make intellegently named lists for the first name, last name, height, weight and age of each person. So, five lists in total.

# %%
# Create first names list
first_names = ["Jennifer", "David", "Courtney", "Lisa", "Matt"]

# Create last names list
last_names = ["Aniston", "Schwimmer", "Cox", "Kudrow", "LeBlanc"]

# Create height list (in meters)
height = [1.65, 1.85, 1.65, 1.73, 1.75]

# Create weight list (in kilograms)
weight = [45, 89, 57, 56, 77]

# Create age list 
ages = [57, 59, 62, 63, 59]

# %% [markdown]
# **E.2.2** Now create a new list that calculates the BMI of each person using the lists you created before

# %%
# Calculate BMI (BMI = weight/ height squared)

# From brute-force
BMI_brute_force = [weight[0]/(height[0]**2), weight[1]/(height[1]**2), weight[2]/(height[2]**2), weight[3]/(height[3]**2), weight[4]/(height[4]**2)] 

# From for loop:
BMI_for_loop = [0, 0, 0, 0, 0]
for i in range(len(BMI_for_loop)):
    BMI_for_loop[i] = weight[i] / (height[i]**2)
    i = i + 1

# Compare brute-force and for loop
print(BMI_brute_force)
print(BMI_for_loop)
# Out:
# [16.528925619834713, 26.004382761139514, 20.936639118457304, 18.710949246550168, 25.142857142857142]
# [16.528925619834713, 26.004382761139514, 20.936639118457304, 18.710949246550168, 25.142857142857142]

# %% [markdown]
# **E.2.3** Look up the weight classification of each person based on their BMI (what's a good source for this, who do you trust?). Create a new list with this information for each person. (Don't judge, we live in Louisiana, which is not known for healthfood.)

# %% [markdown]
# <span style="color:red"> I chose to trust the CDC because it is a credible site.</span>

# %%
# BMI Classifications

# Thresholds
    # underweight: BMI < 18.5
    # healthy: 18.5 <= BMI < 25
    # overweight: 25 <= BMI < 30
    # obesity: 30 < BMI

BMI_classification = [0] * len(BMI_brute_force)

# Classify based on BMI using for loop
for i in range(len(BMI_for_loop)):
    if BMI_for_loop[i] < 18.5:
        BMI_classification[i] = "underweight"
        print("underweight")
    elif 18.5 <= BMI_for_loop[i] < 25:
        BMI_classification[i] = "healthy"
        print("healthy")
    elif 25 <= BMI_for_loop[i] < 30:
        BMI_classification[i] = "overweight"
        print("overweight")
    else:
        BMI_classification[i] = "obese"
        print("obese")

print(BMI_classification)
# Out:
# underweight
# overweight
# healthy
# healthy
# overweight
# ['underweight', 'overweight', 'healthy', 'healthy', 'overweight']

# %% [markdown]
# **E.2.3** Let's practice some print statements and iterate manually through the people on your lists.
#
# For each person, print out something like: "First_name last_name, age xx, has a height of xx units and weight of xx units, giving them a body mass index (BMI) of xx, making them yy" where yy is if they are normal, obese, etc.

# %%
print(f"{first_names[0]} {last_names[0]} has a height of {height[0]} meters and a weight of {weight[0]} kilograms, giving them a body mass index (BMI) of {BMI_brute_force[0]}, making them {BMI_classification[0]}")
print(f"{first_names[1]} {last_names[1]} has a height of {height[1]} meters and a weight of {weight[1]} kilograms, giving them a body mass index (BMI) of {BMI_brute_force[1]}, making them {BMI_classification[1]}")
print(f"{first_names[2]} {last_names[2]} has a height of {height[2]} meters and a weight of {weight[2]} kilograms, giving them a body mass index (BMI) of {BMI_brute_force[2]}, making them {BMI_classification[2]}")
print(f"{first_names[3]} {last_names[3]} has a height of {height[3]} meters and a weight of {weight[3]} kilograms, giving them a body mass index (BMI) of {BMI_brute_force[3]}, making them {BMI_classification[3]}")
print(f"{first_names[4]} {last_names[4]} has a height of {height[4]} meters and a weight of {weight[4]} kilograms, giving them a body mass index (BMI) of {BMI_brute_force[4]}, making them {BMI_classification[4]}")
# Out:
# Jennifer Aniston has a height of 1.65 meters and a weight of 45 kilograms, giving them a body mass index (BMI) of 16.528925619834713, making them underweight
# David Schwimmer has a height of 1.85 meters and a weight of 89 kilograms, giving them a body mass index (BMI) of 26.004382761139514, making them overweight
# Courtney Cox has a height of 1.65 meters and a weight of 57 kilograms, giving them a body mass index (BMI) of 20.936639118457304, making them healthy
# Lisa Kudrow has a height of 1.73 meters and a weight of 56 kilograms, giving them a body mass index (BMI) of 18.710949246550168, making them healthy
# Matt LeBlanc has a height of 1.75 meters and a weight of 77 kilograms, giving them a body mass index (BMI) of 25.142857142857142, making them overweight

# %% [markdown]
# **E.2.4** Now add/append your information to each of the lists, and do the same print statement for you. Make a resolution to eat more veggies.

# %%
first_names.append('Maya')
last_names.append('Maes-Johnson')
height.append(1.55)
weight.append(54)
ages.append(24)

my_BMI = weight[5] / (height[5]**2)
BMI_for_loop.append(my_BMI)

print(first_names[5])
print(last_names[5])
print(height[5])
print(weight[5])
print(ages[5])
print(BMI_for_loop[5])
# Out:
# Maya
# Maes-Johnson
# 1.55
# 54
# 24
# 22.476586888657646

# %% [markdown]
# When you are done with your lab, upload this document to your github folder on the class site. Then submit a url link to the completed lab, along with a screenshot of your completed Ch 2 score in datacamp, to the assignment tab in Moodle.

# %% [markdown]
# # Scratch

# %%
# this is an area of the notebook you can mess around and test things out, if you don't want to put it above
