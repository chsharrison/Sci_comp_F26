# %% [markdown]
# put your name, etc here

# %%
# Taherunnesa Rahi

# %% [markdown]
# # Lecture 1.2

# %% [markdown]
# Wed Aug 24th, 2026
#
# All labs are due Sunday at midnight
#
# Lecture Agenda:
# * debriefing on first class and homework, how's it going?
# * logistics of github, downloading this Lab 1.2 notebook
# * commenting and markup in notebooks
# * workflow for the class

# %% [markdown]
# In general, we will do warmup exercises and lab exercises in a jupyter notebook. For most classes, you will download the notebook from github, open it on your local computer, and then upload your completed work back on github in your folder. Then in the assignment tab in Moodle, submit a url link to the completed lab, along with a screenshot of your completed score for the chapter(s) assigned in datacamp.

# %%
# here is an example of code commenting. The # symbol means everything on this line will be ignored

# %% [markdown]
# Here is an example of markdown text. Because this cell is in markdown mode it will also be ignored by the python shell

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# You created a github account and sent Dr. Harrison your account name in Lab 1.1 to be added to the class github.
#
# Now in our class github site, create a folder for yourself where you will submit your jupyter notebooks. The easiest way to do this is to create a new file that is a placeholder document in the new folder. You can delete it later.

# %% [markdown]
# ## Warmup exercises

# %% [markdown]
# As you are doing these exercises, get familiar with jupyter notebook commands
# https://towardsdatascience.com/jypyter-notebook-shortcuts-bf0101a98330
#
# and markdown text https://medium.com/@ingeh/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed
#
# These exercises are based on what you have learned previously. Feel free to go look at what you did in datacamp to figure out how to answer them.

# %% [markdown]
# **W.1** Define and assign values to three variables of the three types we learned about Monday: integer, floating point, string and boolian.
#
# Note you can add more cells below by pressing the + button above or typing [esc] to command mode, then [b] to enter a cell below, or [a] to enter a cell above. See the link above for more commands

# %%
# Define variables 
integer = 25
float = 5.5
string = "hello"
boolean = True

# %% [markdown]
# **W.2** Print out the value and check the type of each variable

# %%
# Print the value and type of the integer variable
print(integer)
print(type(integer))
# Out:
# 25
# <class 'int'>

# %%
# Print the value and type of the floating point variable
print(float)
print(type(float))
# Out:
# 5.5
# <class 'float'>

# %%
# Print the value and type of the string variable
print(string)
print(type(string))
# Out:
# hello
# <class 'str'>

# %%
# Print the value and type of the Boolean variable
print(boolean)
print(type(boolean))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# **W.3** Create a new variable that saves the value of the float variable as a string. Print it out

# %%
#Create new variable and assigning a string value
new_variable = str(float)

# %%
# Print the new value and its type
print(new_variable)
print(type(new_variable))
# Out:
# 5.5
# <class 'str'>

# %% [markdown]
# **W.4** Using multiplication of a variable, print out the text "Bueno Bueno Bueno Bueno Bueno" (Shoutout to Monsieur Periné https://youtu.be/JGL-eQAAxGs see 10:45)

# %%
#Define the variable
muy_bueno = "Bueno "

# %%
#Multiple str type variable by a number results in attaching multiple  strings.
muy_bueno * 5
# Out:
# 'Bueno Bueno Bueno Bueno Bueno '

# %% [markdown]
# **W.5** Do the same thing using addtion

# %%
muy_bueno + muy_bueno + muy_bueno + muy_bueno + muy_bueno
# Out:
# 'Bueno Bueno Bueno Bueno Bueno '

# %% [markdown]
# **W.6** If you add an int and a float, what is the resulting variable type? Demonstrate

# %%
#Define variables
x = 1
y = 1.5

# %%
#Verify type of the integer variable
type(x)
# Out:
# int

# %%
#Verify type of the float variable
type(y)
# Out:
# float

# %%
#Add both
z = x + y

# %%
#Resulting variable is a float
type(z)
# Out:
# float

# %% [markdown]
# **W.7** Can you convert a Boolian to an interger type variable? If so, what is the resulting value? What happens if you convert a float to an int?

# %% [markdown]
#  Yes, you can convert a Boolian to an integer. The resulting value will be a number, 1 for True and 0 for False. In addition, when I converted a float to integer the resulting integer value was a round number.

# %%
# convert a Boolian to int 
# in the case of True it output value is a 1
int(True)
# Out:
# 1

# %%
# in the case of False the result value is a zero
int(False)
# Out:
# 0

# %%
#Converting a float value to integer, the resulted value is round to integer.
int(2.6)
# Out:
# 2

# %% [markdown]
# # Lab 1.2

# %% [markdown]
# ## Lab Exercises

# %% [markdown]
# **E.1** Complete Ch 2 of Introduction to Python in datacamp.

# %% [markdown]
# **E.2** Below you will spend time practicing what you have learned in Ch 2. Use a comination of code, code commenting, and markdown text to take notes. Make sure you investigate how python syntax works and understand what you are doing, and what went wrong if you have any issues. You can refer to this document later if you need to review, so give future you lots of commenting to be helpful.

# %% [markdown]
# **E.2.1** Let's work on lists, indexing and printing out elements of lists.
#
# We are going to calculate the BMI of five family members (or friends/colleaues if you have a small family, or famous people/politicians/atheletes if you really don't like talking to people, they just have to be adults and you need their data). Make intellegently named lists for the first name, last name, height, weight and age of each person. So, five lists in total.

# %%
firstname = ["Ferdous", "Yazdaan", "Kohinur", "Raihan", "Borhan"]

surname = ["Kabir", "Kabir", "Rima", "Uddin", "Uddin"]

height = [68, 70, 62, 70, 67]

weight = [170, 165, 135, 180, 160]

age = [35, 25, 32, 30, 40]

# %% [markdown]
# **E.2.2** Now create a new list that calculates the BMI of each person using the lists you created before

# %%
BMI = [
    (weight[0] * 703 / (height[0]) ** 2),
    (weight[1] * 703 / (height[1]) ** 2),
    (weight[2] * 703 / (height[2]) ** 2),
    (weight[3] * 703 / (height[3]) ** 2),
    (weight[4] * 703 / (height[4]) ** 2)
]

# Print the BMI list
print(BMI)
# Out:
# [25.845588235294116, 23.672448979591838, 24.689125910509887, 25.824489795918367, 25.056805524615726]

# %% [markdown]
# **E.2.3** Look up the weight classification of each person based on their BMI (what's a good source for this, who do you trust?). Create a new list with this information for each person. (Don't judge, we live in Louisiana, which is not known for healthfood.)

# %% [markdown]
#  Following the Center for Disease Control and Prevention BMI categories (https://www.cdc.gov/bmi/adult-calculator/bmi-categories.html)

# %%
# BMI category to each person
BMI_cat = [
    "Overweight",
    "Healthy Weight",
    "Healthy Weight",
    "Overweight",
    "Overweight"
]

# Print the BMI categories
print(BMI_cat)
# Out:
# ['Overweight', 'Healthy Weight', 'Healthy Weight', 'Overweight', 'Overweight']

# %% [markdown]
# **E.2.3** Let's practice some print statements and iterate manually through the people on your lists.
#
# For each person, print out something like: "First_name last_name, age xx, has a height of xx units and weight of xx units, giving them a body mass index (BMI) of xx, making them yy" where yy is if they are normal, obese, etc.

# %%
# BMI interpretation statement
print(
    firstname[0], surname[0], ", age", age[0],
    ", has a height of", height[0], "inches and a weight of",
    weight[0], "pounds, giving them a body mass index (BMI) of",
    BMI[0], "making them fall into the category of", BMI_cat[0], ".",

    firstname[1], surname[1], ", age", age[1],
    ", has a height of", height[1], "inches and a weight of",
    weight[1], "pounds, giving them a body mass index (BMI) of",
    BMI[1], "making them fall into the category of", BMI_cat[1], ".",

    firstname[2], surname[2], ", age", age[2],
    ", has a height of", height[2], "inches and a weight of",
    weight[2], "pounds, giving them a body mass index (BMI) of",
    BMI[2], "making them fall into the category of", BMI_cat[2], ".",

    firstname[3], surname[3], ", age", age[3],
    ", has a height of", height[3], "inches and a weight of",
    weight[3], "pounds, giving them a body mass index (BMI) of",
    BMI[3], "making them fall into the category of", BMI_cat[3], ".",

    firstname[4], surname[4], ", age", age[4],
    ", has a height of", height[4], "inches and a weight of",
    weight[4], "pounds, giving them a body mass index (BMI) of",
    BMI[4], "making them fall into the category of", BMI_cat[4], ".",

    "According to the Centers for Disease Control and Prevention,",
    "BMI values below 18.5 represent underweight,",
    "values from 18.5 to less than 25 represent healthy weight,",
    "values from 25 to less than 30 represent overweight,",
    "and values of 30 or higher represent obesity."
)
# Out:
# Ferdous Kabir , age 35 , has a height of 68 inches and a weight of 170 pounds, giving them a body mass index (BMI) of 25.845588235294116 making them fall into the category of Overweight . Yazdaan Kabir , age 25 , has a height of 70 inches and a weight of 165 pounds, giving them a body mass index (BMI) of 23.672448979591838 making them fall into the category of Healthy Weight . Kohinur Rima , age 32 , has a height of 62 inches and a weight of 135 pounds, giving them a body mass index (BMI) of 24.689125910509887 making them fall into the category of Healthy Weight . Raihan Uddin , age 30 , has a height of 70 inches and a weight of 180 pounds, giving them a body mass index (BMI) of 25.824489795918367 making them fall into the category of Overweight . Borhan Uddin , age 40 , has a height of 67 inches and a weight of 160 pounds, giving them a body mass index (BMI) of 25.056805524615726 making them fall into the category of Overweight . According to the Centers for Disease Control and Prevention, BMI values below 18.5 represent underweight, values from 18.5 to less than 25 represent healthy weight, values from 25 to less than 30 represent overweight, and values of 30 or higher represent obesity.

# %% [markdown]
# **E.2.4** Now add/append your information to each of the lists, and do the same print statement for you. Make a resolution to eat more veggies.

# %%
# Append my information to each list
firstname_2 = firstname + ["Taherunnesa"]
surname_2 = surname + ["Rahi"]
height_2 = height + [62]
weight_2 = weight + [145.5]
age_2 = age + [29]

# %%
# Calculate my BMI
BMI_2 = BMI + [(weight_2[5] * 703 / (height_2[5]) ** 2)]

# %%
print(BMI_2)
# Out:
# [25.845588235294116, 23.672448979591838, 24.689125910509887, 25.824489795918367, 25.056805524615726, 26.6093912591051]

# %%
# Add my BMI category
BMI_cat_2 = BMI_cat + ["Overweight"]
print(BMI_cat_2)
# Out:
# ['Overweight', 'Healthy Weight', 'Healthy Weight', 'Overweight', 'Overweight', 'Overweight']

# %%
# Print my BMI interpretation statement
print(
    firstname_2[5], surname_2[5],
    ", age", age_2[5],
    ", has a height of", height_2[5], "inches",
    "and a weight of", weight_2[5], "pounds,",
    "giving them a body mass index (BMI) of", BMI_2[5],
    "making them fall into the category of", BMI_cat_2[5], ".",
    "According to the Centers for Disease Control and Prevention,",
    "BMI values below 18.5 represent underweight,",
    "values from 18.5 to less than 25 represent healthy weight,",
    "values from 25 to less than 30 represent overweight,",
    "and values of 30 or higher represent obesity.",
    "I will try to include more vegetables in my diet."
)
# Out:
# Taherunnesa Rahi , age 29 , has a height of 62 inches and a weight of 145.5 pounds, giving them a body mass index (BMI) of 26.6093912591051 making them fall into the category of Overweight . According to the Centers for Disease Control and Prevention, BMI values below 18.5 represent underweight, values from 18.5 to less than 25 represent healthy weight, values from 25 to less than 30 represent overweight, and values of 30 or higher represent obesity. I will try to include more vegetables in my diet.

# %% [markdown]
# When you are done with your lab, upload this document to your github folder on the class site. Then submit a url link to the completed lab, along with a screenshot of your completed Ch 2 score in datacamp, to the assignment tab in Moodle.

# %% [markdown]
# # Scratch

# %%
# this is an area of the notebook you can mess around and test things out, if you don't want to put it above
