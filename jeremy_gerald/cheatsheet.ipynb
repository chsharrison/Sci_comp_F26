# %%
# How to import CSV files into NumPy (genfromtxt is recommended, but np.loadtxt is best for pure numerical data.)
    #data = np.genfromtxt('house_data.csv', delimiter=',', skip_header=1)
    #print(data)

                #or

    #data = np.loadtxt('house_data.csv', delimiter=',')
    #print(data)

#less than >
#less than or equal to >=
#not equal !=
#exactly equal ==
#greater than <
#greater than or equal to <=

#if elif Else 
#if subject modifier variable ## if it fails, it goes to the next elif or else
#elif subject modifier variable ## if it fails, it goes to the else or subsequent elifs

#np.logical_and()     operator equivilent &    Returns True if both elements are True.
#np.logical_or()      operator equivalent |    Returns True if at least one element is True.
#np.logical_not()     operator equivalent ~    Inverts the values (True becomes False).
#np.logical_xor()     operator equivalent ^    Returns True if exactly one element is True (not both).

#panda
#import pandas as pd
#how to import or read CSV files: variable = pd.read_csv("path/to/name.csv", index_col=0)

#GET COLUMN
#how to get the area column as a pandas series and not a dataframe in pandas ## area os tje desired data
#brics["area"]

                #or

#brics.loc[:,"area")
#brics.iloc[:,2]

#COMPARE
#brics["area"] > 8  ###this will generate a boolean dataset

#to store the data series:
#is_huge = brics["area"] > 8

#SUBSET DF
#brics[is_huge]
#can be done as a one-liner
#brics[brics["area"] > 8]

# Boolean operators in pandas
#np.logical_and(brics["area"] > 8, brics["area" < 10) generates a boolean dataset that displays areas greater than 8 and less than 10

#brics[np.logical_and[brics["area"] > 8, brics{"area"] < 10] to get the entire dataset; it must all be in square brackets 


#import pandas as pd
#cars = pd.read_csv('cars.csv', index_col = 0)

# Extract cars_per_cap column as a Series: cpc
#cpc = cars["cars_per_cap"]

# Create many_cars: boolean Series where cpc is greater than 500
#many_cars = cpc > 500

# Create car_maniac: subset cars using many_cars
#car_maniac = cars[many_cars]

# Print car_maniac
#print(car_maniac)
