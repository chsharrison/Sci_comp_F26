# %% [markdown]
# put your name, etc here

# %% [markdown]
# # Sana Raza

# %% [markdown]
# # Lecture 1.2

# %% [markdown]
# Wed Aug 24th, 2026
#
# All labs are due Sunday at midnight
#
# Lecture Agenda:
# * debriefing on first class and homework, how's it going?
# * logistics of github, downloading this Lab 1.2 notebook
# * commenting and markup in notebooks
# * workflow for the class

# %% [markdown]
# In general, we will do warmup exercises and lab exercises in a jupyter notebook. For most classes, you will download the notebook from github, open it on your local computer, and then upload your completed work back on github in your folder. Then in the assignment tab in Moodle, submit a url link to the completed lab, along with a screenshot of your completed score for the chapter(s) assigned in datacamp.

# %%
# here is an example of code commenting. The # symbol means everything on this line will be ignored

# %% [markdown]
# Here is an example of markdown text. Because this cell is in markdown mode it will also be ignored by the python shell

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# You created a github account and sent Dr. Harrison your account name in Lab 1.1 to be added to the class github.
#
# Now in our class github site, create a folder for yourself where you will submit your jupyter notebooks. The easiest way to do this is to create a new file that is a placeholder document in the new folder. You can delete it later.

# %% [markdown]
# ## Warmup exercises

# %% [markdown]
# As you are doing these exercises, get familiar with jupyter notebook commands
# https://towardsdatascience.com/jypyter-notebook-shortcuts-bf0101a98330
#
# and markdown text https://medium.com/@ingeh/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed
#
# These exercises are based on what you have learned previously. Feel free to go look at what you did in datacamp to figure out how to answer them.

# %% [markdown]
# **W.1** Define and assign values to three variables of the three types we learned about Monday: integer, floating point, string and boolian.
#
# Note you can add more cells below by pressing the + button above or typing [esc] to command mode, then [b] to enter a cell below, or [a] to enter a cell above. See the link above for more commands

# %%
# Initiating the variable and assigning it to an integer
p = 2

# %%
# Initiating the variable and assigning it to a float

q = 2.3

# %%
# Initiating the variable and assigning it a string

r = 'Hello, world!'

# %%
# Initiating the variable and assigning it to a Boolean

s = True

# %% [markdown]
# **W.2** Print out the value and check the type of each variable

# %%
#Printing the value of the type of the variable

print(p)
# Out:
# 2

# %%
#Printing the value of the type of the variable

print(q)
# Out:
# 2.3

# %%
#Printing the value of the type of the variable

print(r)
# Out:
# Hello, world!

# %%
#Printing the value of the type of the variable

print(s)
# Out:
# True

# %%
#Printing the value of the type of the variable

print(type(p))
# Out:
# <class 'int'>

# %%
#Printing the type of the variable


print(type(q))
# Out:
# <class 'float'>

# %%
#Printing the type of the variable


print(type(r))
# Out:
# <class 'str'>

# %%
#Printing the type of the variable


print(type(s))
# Out:
# <class 'bool'>

# %% [markdown]
# **W.3** Create a new variable that saves the value of the float variable as a string. Print it out

# %%
# str is used to convert into string type

new_variable = str(q)

# %%
# Checking the type of the variable

print(type(new_variable))
# Out:
# <class 'str'>

# %%
print(new_variable)
# Out:
# 2.3

# %% [markdown]
# **W.4** Using multiplication of a variable, print out the text "Bueno Bueno Bueno Bueno Bueno" (Shoutout to Monsieur Periné https://youtu.be/JGL-eQAAxGs see 10:45)

# %%
# Using the value of 's' for the multiplication

s = "Bueno "

# %%
# In order to print Bueno five times,  I need to multiply 's' with 5

print(s*5)
# Out:
# Bueno Bueno Bueno Bueno Bueno

# %% [markdown]
# **W.5** Do the same thing using addtion

# %%
# Initiating 'addition' as a variable to get Bueno printed 5 times

addition = s + s + s + s + s

# %%
print(addition)
# Out:
# Bueno Bueno Bueno Bueno Bueno

# %% [markdown]
# **W.6** If you add an int and a float, what is the resulting variable type? Demonstrate

# %%
# Considering 'a' to be the variable being initiated
# 7 is an int and 3.4 is a float

a = 7 + 3.4

# %%
# The resulting type of the variable is float

print(type(a))
# Out:
# <class 'float'>

# %% [markdown]
# **Answer**:
#
# Adding an integer and a float together produces a float.

# %% [markdown]
# **W.7** Can you convert a Boolian to an interger type variable? If so, what is the resulting value? What happens if you convert a float to an int?

# %% [markdown]
# **Answer**:
#
# Yes, we can convert Boolean into an integer. In case, I use 'True' to convert to an integer, I would get 1 in the result. If I use 'False' in the integer, then I would get 0 in the result. I can also convert float into an integer.
#
# Demonstrating both below

# %%
# Initiating the Boolean variable now
is_boolean = False

# %%
# Using 'int' to convert the Boolean into integer 
is_integer = int(is_boolean)

# %%
print(is_integer)
# Out:
# 0

# %%
# Initiating another Boolean variable now
is_boolean = True

# %%
# Using 'int' to convert the Boolean into integer 
is_integer = int(is_boolean)

# %%
print(is_integer)
# Out:
# 1

# %%
# Initiating a float variable

x = 3.878787878

# %%
# Converting float into an integer

y = int(x)

# %%
# Printing the variable 'y'

print(y)
# Out:
# 3

# %% [markdown]
# # Lab 1.2

# %% [markdown]
# ## Lab Exercises

# %% [markdown]
# **E.1** Complete Ch 2 of Introduction to Python in datacamp.

# %% [markdown]
# **E.2** Below you will spend time practicing what you have learned in Ch 2. Use a comination of code, code commenting, and markdown text to take notes. Make sure you investigate how python syntax works and understand what you are doing, and what went wrong if you have any issues. You can refer to this document later if you need to review, so give future you lots of commenting to be helpful.

# %% [markdown]
# **E.2.1** Let's work on lists, indexing and printing out elements of lists.
#
# We are going to calculate the BMI of five family members (or friends/colleaues if you have a small family, or famous people/politicians/atheletes if you really don't like talking to people, they just have to be adults and you need their data). Make intellegently named lists for the first name, last name, height, weight and age of each person. So, five lists in total.

# %%
# Initiating a list with the first name of my family members
first_name = ['Aiman', 'Warisha', 'Zainab', 'Maryam', 'Asma']

# Initiating a list with the last name of my family members

last_name = ['Ali', 'Rana', 'Fatima', 'Nawaz', 'Moin']

# Initiating a list with 5 family members height. Considering the height to be in metres
height = [1.7, 1.6, 1.5, 1.4, 1.3] 

# Initiating a list with 5 family members weight. Considering the weight to be in kg
weight = [90, 81, 50, 55, 65]
age = [25, 29, 18, 19, 50]

# %% [markdown]
# **Answer**:
#
#
# Using the following link for BMI formula
#
# https://www.cdc.gov/growth-chart-training/hcp/using-bmi/calculating-bmi.html

# %% [markdown]
# **E.2.2** Now create a new list that calculates the BMI of each person using the lists you created before

# %%
# The formula for BMI:

# BMI = weight(kg)/height**2 (meters)

# %%
# Creating a new list to calculates the BMI

my_family_BMI = [weight[0]/(height[0]**2),
                weight[1]/(height[1]**2),
                weight[2]/(height[2]**2),
                weight[3]/(height[3]**2),
                weight[4]/(height[4]**2)]

# %%
print(my_family_BMI)
# Out:
# [31.14186851211073, 31.640624999999993, 22.22222222222222, 28.061224489795922, 38.46153846153846]

# %% [markdown]
# **E.2.3** Look up the weight classification of each person based on their BMI (what's a good source for this, who do you trust?). Create a new list with this information for each person. (Don't judge, we live in Louisiana, which is not known for healthfood.)

# %% [markdown]
# **Formulas and Links**:
#
# Using the BMI classification from CDC from the following link
#
# https://www.cdc.gov/bmi/adult-calculator/bmi-categories.html
#
# Using BMI = weight(kg)/height**2 (meters)
#
# I chose the website of CDC as it is by U.S. Centres for Disease Control and Prevention which mean it is a credible source.

# %%
# Classifying weights based on the BMI

my_family_weight_classification = ["Class 1 Obese", "Class 1 Obese", "Healthy Weight", "Overweight", "Class 2 Obese"]

# %% [markdown]
# **E.2.3** Let's practice some print statements and iterate manually through the people on your lists.
#
# For each person, print out something like: "First_name last_name, age xx, has a height of xx units and weight of xx units, giving them a body mass index (BMI) of xx, making them yy" where yy is if they are normal, obese, etc.

# %%
# Printing for the first person in my family

print(first_name[0], last_name[0], ", age", age[0], "has a height of", height[0], "m and weight of", weight[0], "kg, giving them a body mass index (BMI) of", my_family_BMI[0],", making them", my_family_weight_classification[0])
# Out:
# Aiman Ali , age 25 has a height of 1.7 m and weight of 90 kg, giving them a body mass index (BMI) of 31.14186851211073 , making them Class 1 Obese

# %%
# Printing for the second person in my family

print(first_name[1], last_name[1], ", age", age[1], "has a height of", height[1], "m and weight of", weight[1], "kg, giving them a body mass index (BMI) of", my_family_BMI[1],", making them", my_family_weight_classification[1])
# Out:
# Warisha Rana , age 29 has a height of 1.6 m and weight of 81 kg, giving them a body mass index (BMI) of 31.640624999999993 , making them Class 1 Obese

# %%
# Printing for the third person in my family

print(first_name[2], last_name[2], ", age", age[2], "has a height of", height[2], "m and weight of", weight[2], "kg, giving them a body mass index (BMI) of", my_family_BMI[2],", making them", my_family_weight_classification[2])
# Out:
# Zainab Fatima , age 18 has a height of 1.5 m and weight of 50 kg, giving them a body mass index (BMI) of 22.22222222222222 , making them Healthy Weight

# %%
# Printing for the fourth person in my family

print(first_name[3], last_name[3], ", age", age[3], "has a height of", height[3], "m and weight of", weight[3], "kg, giving them a body mass index (BMI) of", my_family_BMI[3],", making them", my_family_weight_classification[3])
# Out:
# Maryam Nawaz , age 19 has a height of 1.4 m and weight of 55 kg, giving them a body mass index (BMI) of 28.061224489795922 , making them Overweight

# %%
# Printing for the fifth person in my family

print(first_name[4], last_name[4], ", age", age[4], "has a height of", height[4], "m and weight of", weight[4], "kg, giving them a body mass index (BMI) of", my_family_BMI[4],", making them", my_family_weight_classification[4])
# Out:
# Asma Moin , age 50 has a height of 1.3 m and weight of 65 kg, giving them a body mass index (BMI) of 38.46153846153846 , making them Class 2 Obese

# %% [markdown]
# **E.2.4** Now add/append your information to each of the lists, and do the same print statement for you. Make a resolution to eat more veggies.

# %%
# Adding my name, height, weight and age

my_first_name = first_name + ["Sana"]
my_last_name = last_name + ["Raza"]
my_height = height + [1.60]
my_weight = weight + [53]
my_age = age + [27]

# %%
# Adding my BMI in my 'my_family_BMI' variable

my_bmi = my_family_BMI + [my_weight[5] / (my_height[5]**2)]

# %%
# Printing my BMI

print(my_bmi)
# Out:
# [31.14186851211073, 31.640624999999993, 22.22222222222222, 28.061224489795922, 38.46153846153846, 20.703124999999996]

# %%
# Adding my classification in my 'family_weight_classification' variable

my_weight_and_family_weight_classification = my_family_weight_classification + ["Healthy Weight"]

# %%
# Printing my name along with age, height, weight, and BMI.

print(my_first_name[5], my_last_name[5], ", age", my_age[5],"has a height of", my_height[5], "m and weight of",my_weight[5], "kg, has a body mass index (BMI) of",my_bmi[5], ", placing me in the",my_weight_and_family_weight_classification[5], "category. My resolution is to eat more vegetables.")
# Out:
# Sana Raza , age 27 has a height of 1.6 m and weight of 53 kg, has a body mass index (BMI) of 20.703124999999996 , placing me in the Healthy Weight category. My resolution is to eat more vegetables.

# %%
future_resolution_for_Sana_Raza = print("Eat more veggies, Sana!")
# Out:
# Eat more veggies, Sana!

# %% [markdown]
# When you are done with your lab, upload this document to your github folder on the class site. Then submit a url link to the completed lab, along with a screenshot of your completed Ch 2 score in datacamp, to the assignment tab in Moodle.

# %% [markdown]
# # Scratch

# %%
# this is an area of the notebook you can mess around and test things out, if you don't want to put it above
