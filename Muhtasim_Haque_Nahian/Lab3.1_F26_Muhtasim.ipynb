# %% [markdown]
# Name: Muhtasim Haque Nahian

# %% [markdown]
# Lab Partner: Haoxin Ni

# %% [markdown]
# Let's get in the habit of putting import statements at the top of the notebook.

# %%
# import statements here for numpy and matplotlib

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd  #new package!!

# %%
whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# np         module    <module 'numpy' from 'E:\<...>ges\\numpy\\__init__.py'>
# pd         module    <module 'pandas' from 'E:<...>es\\pandas\\__init__.py'>
# plt        module    <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>

# %%
who
# Out:
# np	 pd	 plt

# %% [markdown]
# # Lab 3.1

# %% [markdown]
# Today we are going to continue working on what we started last time, getting familiar with plotting and continuing to get comfortable with indexing and functions.
#
# I will also show you how to import simple data files. We are using a new package, Pandas, which I will introduce and then you will explore more in datacamp.

# %% [markdown]
# ## Instructions
#
# For each class, download the lab and have it up and running in Jupyter when we begin the class period. This will allow you to code along with the demonstrations and be ready to go. You will be assigned a lab partner. Put their name above.
#
# When you are done with your lab, upload this document to your github folder on the class site. Then submit a url link to the completed lab, along with a screenshot of your **completed score** for the chapter assigned in datacamp to the assignment tab in Moodle.

# %% [markdown]
# # Warmups 3.1

# %% [markdown]
# Please note you do NOT have to finish these warmup exercises before lecture. Go at your own pace. You can work on them later as needed.

# %% [markdown]
# **W.1.** Make a numpy array that goes from 100 to 1000 (including 1000) stepping by 50

# %%
arr1 = np.arange(100,1001,50)
print(arr1)
# Out:
# [ 100  150  200  250  300  350  400  450  500  550  600  650  700  750
#   800  850  900  950 1000]

# %% [markdown]
# **W.2** What is the shape of this array (this is not about plotting, but the size of the array, how many elements does it have? Find this using python)

# %%
arr1.shape
# Out:
# (19,)

# %% [markdown]
# **W.3** Print out the first 5 elements of the array

# %%
print(arr1[0:5])
# Out:
# [100 150 200 250 300]

# %% [markdown]
# **W.4** Print out the last 5 elements of the array

# %%
print(arr1[-5:])
# Out:
# [ 800  850  900  950 1000]

# %% [markdown]
# **W.5** Print out the sith through tenth elements of the array. There should be five elements printed

# %%
print(arr1[5:10])
# Out:
# [350 400 450 500 550]

# %% [markdown]
# **W.6** Plot the array (i.e. plt.plot(x) if x is your array) and make your line red

# %%
plt.plot(arr1, '.-r')
plt.show()

# %% [markdown]
# **W.7** What is being plotted on the x-axis?

# %% [markdown]
# it's a straight line, where the x-axis has the indices and the y-axis has the real values of the array

# %% [markdown]
# **W.8** Label your axes reflecting your answer above and add a title

# %%
from matplotlib.ticker import MaxNLocator
plt.plot(arr1, '.-r')
plt.xlabel('Index', fontweight='bold')
plt.ylabel('Value', fontweight='bold')
plt.title('plot of arr1', fontweight='bold')
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.show()

# %% [markdown]
# **W.9** Now calculate the square of your array, i.e. $x^2$ and plot this vs the first array, i.e. plt.plot(x,$x^2$). What is being plotted on the x-axis now? Label your axes and add a legend.

# %%
arr1_sq = arr1**2
print(arr1_sq)
# Out:
# [  10000   22500   40000   62500   90000  122500  160000  202500  250000
#   302500  360000  422500  490000  562500  640000  722500  810000  902500
#  1000000]

# %%
plt.plot(arr1, arr1_sq, '.-r', label='arr1 squared')
plt.xlabel('arr1', fontweight='bold')
plt.ylabel('arr1_sq', fontweight='bold')
plt.title('arr1 vs arr1_sq', fontweight='bold')
plt.legend()
plt.show()

# %% [markdown]
# Now x-axis is the actual array that I created earlier, and y-axis is the squared value of that array. This produces a parabola-shaped curve.

# %% [markdown]
# # Lecture 3.1

# %% [markdown]
# ## 3.1.1 What are all the questions from the previous labs and material?
# The more basic the better. Let's do some review and make sure we don't leave anyone behind.

# %% [markdown]
# okiesss

# %% [markdown]
# ## 3.1.2 More plotting

# %% [markdown]
# Last time we made the following plot

# %%
# Define the data

start = -2*np.pi
stop = 2*np.pi
#step = np.pi/8
step = np.pi/32 #smaller step

x_2 = np.arange(start,stop+step,step)
print(x_2)
# Out:
# [-6.28318531e+00 -6.18501054e+00 -6.08683577e+00 -5.98866100e+00
#  -5.89048623e+00 -5.79231146e+00 -5.69413668e+00 -5.59596191e+00
#  -5.49778714e+00 -5.39961237e+00 -5.30143760e+00 -5.20326283e+00
#  -5.10508806e+00 -5.00691329e+00 -4.90873852e+00 -4.81056375e+00
#  -4.71238898e+00 -4.61421421e+00 -4.51603944e+00 -4.41786467e+00
#  -4.31968990e+00 -4.22151513e+00 -4.12334036e+00 -4.02516559e+00
#  -3.92699082e+00 -3.82881605e+00 -3.73064128e+00 -3.63246651e+00
#  -3.53429174e+00 -3.43611696e+00 -3.33794219e+00 -3.23976742e+00
#  -3.14159265e+00 -3.04341788e+00 -2.94524311e+00 -2.84706834e+00
#  -2.74889357e+00 -2.65071880e+00 -2.55254403e+00 -2.45436926e+00
#  -2.35619449e+00 -2.25801972e+00 -2.15984495e+00 -2.06167018e+00
#  -1.96349541e+00 -1.86532064e+00 -1.76714587e+00 -1.66897110e+00
#  -1.57079633e+00 -1.47262156e+00 -1.37444679e+00 -1.27627202e+00
#  -1.17809725e+00 -1.07992247e+00 -9.81747704e-01 -8.83572934e-01
#  -7.85398163e-01 -6.87223393e-01 -5.89048623e-01 -4.90873852e-01
#  -3.92699082e-01 -2.94524311e-01 -1.96349541e-01 -9.81747704e-02
#  -2.13162821e-14  9.81747704e-02  1.96349541e-01  2.94524311e-01
#   3.92699082e-01  4.90873852e-01  5.89048623e-01  6.87223393e-01
#   7.85398163e-01  8.83572934e-01  9.81747704e-01  1.07992247e+00
#   1.17809725e+00  1.27627202e+00  1.37444679e+00  1.47262156e+00
#   1.57079633e+00  1.66897110e+00  1.76714587e+00  1.86532064e+00
#   1.96349541e+00  2.06167018e+00  2.15984495e+00  2.25801972e+00
#   2.35619449e+00  2.45436926e+00  2.55254403e+00  2.65071880e+00
#   2.74889357e+00  2.84706834e+00  2.94524311e+00  3.04341788e+00
#   3.14159265e+00  3.23976742e+00  3.33794219e+00  3.43611696e+00
#   3.53429174e+00  3.63246651e+00  3.73064128e+00  3.82881605e+00
#   3.92699082e+00  4.02516559e+00  4.12334036e+00  4.22151513e+00
#   4.31968990e+00  4.41786467e+00  4.51603944e+00  4.61421421e+00
#   4.71238898e+00  4.81056375e+00  4.90873852e+00  5.00691329e+00
#   5.10508806e+00  5.20326283e+00  5.30143760e+00  5.39961237e+00
#   5.49778714e+00  5.59596191e+00  5.69413668e+00  5.79231146e+00
#   5.89048623e+00  5.98866100e+00  6.08683577e+00  6.18501054e+00
#   6.28318531e+00]

# %%
# plot the data

plt.plot(x_2, np.sin(x_2))
plt.xlabel('x')
plt.ylabel('y')
plt.title('y = sin(x)')
# Out:
# Text(0.5, 1.0, 'y = sin(x)')

# %% [markdown]
# This uses an implict plotting style, instead of an object oriented approach where the elements of the plot are defined at the beginning and then can be manipulated

# %% [markdown]
# ![matplotlib_plotting_types.png](attachment:70efbaf9-a46c-484d-9821-ea3387397729.png)

# %% [markdown]
# What we did last week was quick and dirty, and works great for quick plots. Sometimes you want more control. Don't worry about this for now, just know it exists in case you need it later or you see it somewhere.

# %%
# let's go over an example plot in the old matplotlib documenation gallery

#d efine some data and give it some labels
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
print(labels)
print(men_means)
print(women_means)
print(men_std)
print(women_std)
# Out:
# ['G1', 'G2', 'G3', 'G4', 'G5']
# [20, 35, 30, 35, 27]
# [25, 32, 34, 20, 25]
# [2, 3, 4, 1, 2]
# [3, 5, 2, 3, 3]

# %%
plt.bar?
# Out:
# Signature:
# plt.bar(
#     x: 'float | ArrayLike',
#     height: 'float | ArrayLike',
#     width: 'float | ArrayLike' = 0.8,
#     bottom: 'float | ArrayLike | None' = None,
#     *,
#     align: "Literal['center', 'edge']" = 'center',
#     data: 'DataParamType' = None,
#     **kwargs,
# ) -> 'BarContainer'
# Docstring:
# Make a bar plot.
#
# The bars are positioned at *x* with the given *align*\ment. Their
# dimensions are given by *height* and *width*. The vertical baseline
# is *bottom* (default 0).
#
# Many parameters can take either a single value applying to all bars
# or a sequence of values, one for each bar.
#
# Parameters
# ----------
# x : float or array-like
#     The x coordinates of the bars. See also *align* for the
#     alignment of the bars to the coordinates.
#
#     Bars are often used for categorical data, i.e. string labels below
#     the bars. You can provide a list of strings directly to *x*.
#     ``bar(['A', 'B', 'C'], [1, 2, 3])`` is often a shorter and more
#     convenient notation compared to
#     ``bar(range(3), [1, 2, 3], tick_label=['A', 'B', 'C'])``. They are
#     equivalent as long as the names are unique. The explicit *tick_label*
#     notation draws the names in the sequence given. However, when having
#     duplicate values in categorical *x* data, these values map to the same
#     numerical x coordinate, and hence the corresponding bars are drawn on
#     top of each other.
#
# height : float or array-like
#     The height(s) of the bars.
#
#     Note that if *bottom* has units (e.g. datetime), *height* should be in
#     units that are a difference from the value of *bottom* (e.g. timedelta).
#
# width : float or array-like, default: 0.8
#     The width(s) of the bars.
#
#     Note that if *x* has units (e.g. datetime), then *width* should be in
#     units that are a difference (e.g. timedelta) around the *x* values.
#
# bottom : float or array-like, default: 0
#     The y coordinate(s) of the bottom side(s) of the bars.
#
#     Note that if *bottom* has units, then the y-axis will get a Locator and
#     Formatter appropriate for the units (e.g. dates, or categorical).
#
# align : {'center', 'edge'}, default: 'center'
#     Alignment of the bars to the *x* coordinates:
#
#     - 'center': Center the base on the *x* positions.
#     - 'edge': Align the left edges of the bars with the *x* positions.
#
#     To align the bars on the right edge pass a negative *width* and
#     ``align='edge'``.
#
# Returns
# -------
# `.BarContainer`
#     Container with all the bars and optionally errorbars.
#
# Other Parameters
# ----------------
# color : :mpltype:`color` or list of :mpltype:`color`, optional
#     The colors of the bar faces. This is an alias for *facecolor*.
#     If both are given, *facecolor* takes precedence.
#
# facecolor : :mpltype:`color` or list of :mpltype:`color`, optional
#     The colors of the bar faces.
#     If both *color* and *facecolor are given, *facecolor* takes precedence.
#
# edgecolor : :mpltype:`color` or list of :mpltype:`color`, optional
#     The colors of the bar edges.
#
# linewidth : float or array-like, optional
#     Width of the bar edge(s). If 0, don't draw edges.
#
# tick_label : str or list of str, optional
#     The tick labels of the bars.
#     Default: None (Use default numeric labels.)
#
# label : str or list of str, optional
#     A single label is attached to the resulting `.BarContainer` as a
#     legend label for the whole dataset.
#     If a list is provided, it must be the same length as *x* and
#     labels the individual bars. Repeated labels are not de-duplicated
#     and will cause repeated label entries, so this is best used when
#     bars also differ in style (e.g., by passing a list to *color*).
#
#     Tip: Use `.bar_label` to place labels on the bars.
#
# xerr, yerr : float or array-like of shape(N,) or shape(2, N), optional
#     If not *None*, add horizontal / vertical errorbars to the bar tips.
#     The values are +/- sizes relative to the data:
#
#     - scalar: symmetric +/- values for all bars
#     - shape(N,): symmetric +/- values for each bar
#     - shape(2, N): Separate - and + values for each bar. First row
#       contains the lower errors, the second row contains the upper
#       errors.
#     - *None*: No errorbar. (Default)
#
#     This is a convenience shortcut for an extra `~.axes.Axes.errorbar`
#     call. See its documentation and
#     :doc:`/gallery/statistics/errorbar_features` for an example on
#     the usage of *xerr* and *yerr*.
#
# ecolor : :mpltype:`color` or list of :mpltype:`color`, default: 'black'
#     The line color of the errorbars.
#     Multiple colors are only supported if the errorbars do not have
#     caps. If you need individually colored errorbars with caps, instead
#     use explicit `~.axes.Axes.errorbar` calls for each data point.
#
# capsize : float, default: :rc:`errorbar.capsize`
#    The length of the error bar caps in points.
#
# error_kw : dict, optional
#     Dictionary of keyword arguments to be passed to the
#     `~.Axes.errorbar` method. Values of *ecolor* or *capsize* defined
#     here take precedence over the independent keyword arguments.
#
# log : bool, default: False
#     If *True*, set the y-axis to be log scale.
#
# data : indexable object, optional
#     If given, all parameters also accept a string ``s``, which is
#     interpreted as ``data[s]`` if ``s`` is a key in ``data``.
#
# **kwargs : `.Rectangle` properties
#
# Properties:
#     agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#     alpha: float or None
#     angle: unknown
#     animated: bool
#     antialiased or aa: bool or None
#     bounds: (left, bottom, width, height)
#     capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#     clip_box: `~matplotlib.transforms.BboxBase` or None
#     clip_on: bool
#     clip_path: Patch or (Path, Transform) or None
#     color: :mpltype:`color`
#     edgecolor or ec: :mpltype:`color` or None
#     edgegapcolor: :mpltype:`color` or None
#     facecolor or fc: :mpltype:`color` or None
#     figure: `~matplotlib.figure.Figure` or `~matplotlib.figure.SubFigure`
#     fill: bool
#     gid: str
#     hatch: {'/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*'}
#     hatch_linewidth: unknown
#     hatchcolor: :mpltype:`color` or 'edge' or None
#     height: unknown
#     in_layout: bool
#     joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#     label: object
#     linestyle or ls: {'-', '--', '-.', ':', '', ...} or (offset, on-off-seq)
#     linewidth or lw: float or None
#     mouseover: bool
#     path_effects: list of `.AbstractPathEffect`
#     picker: None or bool or float or callable
#     rasterized: bool
#     sketch_params: (scale: float, length: float, randomness: float)
#     snap: bool or None
#     transform: `~matplotlib.transforms.Transform`
#     url: str
#     visible: bool
#     width: unknown
#     x: unknown
#     xy: (float, float)
#     y: unknown
#     zorder: float
#
# See Also
# --------
# barh : Plot a horizontal bar plot.
# grouped_bar : Plot multiple datasets as grouped bar plot.
# bar_label : Add labels to bars.
#
# Notes
# -----
#
# .. note::
#
#     This is the :ref:`pyplot wrapper <pyplot_interface>` for `.axes.Axes.bar`.
#
# Stacked bars can be achieved by passing individual *bottom* values per
# bar. See :doc:`/gallery/lines_bars_and_markers/bar_stacked`.
# File:      e:\anaconda\anaconda_installed\lib\site-packages\matplotlib\pyplot.py
# Type:      function

# %%
# now we are going to make a bar plot using plt.bar, but calling it a different way than we did before

width = 0.55       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots() # defining a figure

# plot the data first set of data
ax.bar(labels, men_means, width, yerr = men_std, label = 'Men')
# Out:
# <BarContainer object of 5 artists>

# %%
width = 0.55       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots() # defining a figure

# plot the data first set of data
ax.bar(labels, men_means, width, yerr = men_std, label = 'Men')
# now add the women
ax.bar(labels, women_means, width, yerr = women_std, bottom = men_means, label = "Women")

# note this makes a stacked bar plot
# Out:
# <BarContainer object of 5 artists>

# %%
# now let's add a y-label

width = 0.55       
fig, ax = plt.subplots()
ax.bar(labels, men_means, width, yerr = men_std, label = 'Men')
ax.bar(labels, women_means, width, yerr = women_std, bottom = men_means, label = "Women")

# note these both do the same thing:
#plt.ylabel('Scores')
ax.set_ylabel('Scores')
# Out:
# Text(0, 0.5, 'Scores')

# %%
# add a title and a legend

width = 0.55       
fig, ax = plt.subplots()
ax.bar(labels, men_means, width, yerr = men_std, label = 'Men')
ax.bar(labels, women_means, width, yerr = women_std, bottom = men_means, label = "Women")

# note these both do the same thing:
plt.ylabel('Scores')
#ax.set_ylabel('Scores')

ax.set_title('Scores by group and gender')
ax.legend()

# %% [markdown]
# ## 3.1.3 How to import a text file (the old ways of python)

# %% [markdown]
# We are going to use some data in the scipy lecture notes, which is a great reference:
# m
# http://scipy-lectures.org/intro/numpy/exercises.html#data-statistics
#
# Note that I have downloaded the populations.txt file and put it in the same foler as this notebook, so I can load it without the path in front

# %%
data = np.loadtxt('populations.txt')

# %%
data
# Out:
# array([[ 1900., 30000.,  4000., 48300.],
#        [ 1901., 47200.,  6100., 48200.],
#        [ 1902., 70200.,  9800., 41500.],
#        [ 1903., 77400., 35200., 38200.],
#        [ 1904., 36300., 59400., 40600.],
#        [ 1905., 20600., 41700., 39800.],
#        [ 1906., 18100., 19000., 38600.],
#        [ 1907., 21400., 13000., 42300.],
#        [ 1908., 22000.,  8300., 44500.],
#        [ 1909., 25400.,  9100., 42100.],
#        [ 1910., 27100.,  7400., 46000.],
#        [ 1911., 40300.,  8000., 46800.],
#        [ 1912., 57000., 12300., 43800.],
#        [ 1913., 76600., 19500., 40900.],
#        [ 1914., 52300., 45700., 39400.],
#        [ 1915., 19500., 51100., 39000.],
#        [ 1916., 11200., 29700., 36700.],
#        [ 1917.,  7600., 15800., 41800.],
#        [ 1918., 14600.,  9700., 43300.],
#        [ 1919., 16200., 10100., 41300.],
#        [ 1920., 24700.,  8600., 47300.]])

# %%
# note if the data file is in another folder, I have to add some path information to the file string

data2 = np.loadtxt(r'E:\_MS LSU\OCS 7001 Scientific Computing\populations.txt')
# note this is how it looks in MacOS, it will be different on a Windows PC

# %%
data2
# Out:
# array([[ 1900., 30000.,  4000., 48300.],
#        [ 1901., 47200.,  6100., 48200.],
#        [ 1902., 70200.,  9800., 41500.],
#        [ 1903., 77400., 35200., 38200.],
#        [ 1904., 36300., 59400., 40600.],
#        [ 1905., 20600., 41700., 39800.],
#        [ 1906., 18100., 19000., 38600.],
#        [ 1907., 21400., 13000., 42300.],
#        [ 1908., 22000.,  8300., 44500.],
#        [ 1909., 25400.,  9100., 42100.],
#        [ 1910., 27100.,  7400., 46000.],
#        [ 1911., 40300.,  8000., 46800.],
#        [ 1912., 57000., 12300., 43800.],
#        [ 1913., 76600., 19500., 40900.],
#        [ 1914., 52300., 45700., 39400.],
#        [ 1915., 19500., 51100., 39000.],
#        [ 1916., 11200., 29700., 36700.],
#        [ 1917.,  7600., 15800., 41800.],
#        [ 1918., 14600.,  9700., 43300.],
#        [ 1919., 16200., 10100., 41300.],
#        [ 1920., 24700.,  8600., 47300.]])

# %%
print(data2)
# Out:
# [[ 1900. 30000.  4000. 48300.]
#  [ 1901. 47200.  6100. 48200.]
#  [ 1902. 70200.  9800. 41500.]
#  [ 1903. 77400. 35200. 38200.]
#  [ 1904. 36300. 59400. 40600.]
#  [ 1905. 20600. 41700. 39800.]
#  [ 1906. 18100. 19000. 38600.]
#  [ 1907. 21400. 13000. 42300.]
#  [ 1908. 22000.  8300. 44500.]
#  [ 1909. 25400.  9100. 42100.]
#  [ 1910. 27100.  7400. 46000.]
#  [ 1911. 40300.  8000. 46800.]
#  [ 1912. 57000. 12300. 43800.]
#  [ 1913. 76600. 19500. 40900.]
#  [ 1914. 52300. 45700. 39400.]
#  [ 1915. 19500. 51100. 39000.]
#  [ 1916. 11200. 29700. 36700.]
#  [ 1917.  7600. 15800. 41800.]
#  [ 1918. 14600.  9700. 43300.]
#  [ 1919. 16200. 10100. 41300.]
#  [ 1920. 24700.  8600. 47300.]]

# %%
# you can also download it directly from the url:

data3 = np.loadtxt('http://scipy-lectures.org/_downloads/populations.txt')

# %%
data3
# Out:
# array([[ 1900., 30000.,  4000., 48300.],
#        [ 1901., 47200.,  6100., 48200.],
#        [ 1902., 70200.,  9800., 41500.],
#        [ 1903., 77400., 35200., 38200.],
#        [ 1904., 36300., 59400., 40600.],
#        [ 1905., 20600., 41700., 39800.],
#        [ 1906., 18100., 19000., 38600.],
#        [ 1907., 21400., 13000., 42300.],
#        [ 1908., 22000.,  8300., 44500.],
#        [ 1909., 25400.,  9100., 42100.],
#        [ 1910., 27100.,  7400., 46000.],
#        [ 1911., 40300.,  8000., 46800.],
#        [ 1912., 57000., 12300., 43800.],
#        [ 1913., 76600., 19500., 40900.],
#        [ 1914., 52300., 45700., 39400.],
#        [ 1915., 19500., 51100., 39000.],
#        [ 1916., 11200., 29700., 36700.],
#        [ 1917.,  7600., 15800., 41800.],
#        [ 1918., 14600.,  9700., 43300.],
#        [ 1919., 16200., 10100., 41300.],
#        [ 1920., 24700.,  8600., 47300.]])

# %% [markdown]
# Note that the header information (the names of the data columns) was not imported.

# %%
# what is the shape of the data?
data.shape
# Out:
# (21, 4)

# %% [markdown]
# I want to plot the data in the three columns by year

# %%
# how do I get the years?
data[:,0]
# Out:
# array([1900., 1901., 1902., 1903., 1904., 1905., 1906., 1907., 1908.,
#        1909., 1910., 1911., 1912., 1913., 1914., 1915., 1916., 1917.,
#        1918., 1919., 1920.])

# %%
# how do I get the hare data?
data[:,1]
# Out:
# array([30000., 47200., 70200., 77400., 36300., 20600., 18100., 21400.,
#        22000., 25400., 27100., 40300., 57000., 76600., 52300., 19500.,
#        11200.,  7600., 14600., 16200., 24700.])

# %%
data[:,2]
# Out:
# array([ 4000.,  6100.,  9800., 35200., 59400., 41700., 19000., 13000.,
#         8300.,  9100.,  7400.,  8000., 12300., 19500., 45700., 51100.,
#        29700., 15800.,  9700., 10100.,  8600.])

# %%
data[:,3]
# Out:
# array([48300., 48200., 41500., 38200., 40600., 39800., 38600., 42300.,
#        44500., 42100., 46000., 46800., 43800., 40900., 39400., 39000.,
#        36700., 41800., 43300., 41300., 47300.])

# %%
years = data[:,0]
hares = data[:,1]
lynx = data[:,2]
carrot = data[:,3]

# %%
# let's make a plot hares vs. years
from matplotlib.ticker import MaxNLocator

plt.plot(years, hares, color = 'green')

plt.xlabel('years', fontweight = 'bold')
plt.ylabel('hares', fontweight = 'bold')
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))

# %%
# let's plot the rest of the data and add a legend
from matplotlib.ticker import MaxNLocator

plt.plot(years, hares, color = 'green', label = 'Hares')
plt.plot(years, lynx, color = 'blue', label = 'Lynx')
plt.plot(years, carrot, color = 'orange', label = 'Carrot')

plt.xlabel('years', fontweight = 'bold')
plt.ylabel('population of hares', fontweight = 'bold')
plt.title('population plot', fontweight = 'bold')
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.legend()

# %% [markdown]
# ## 3.2.3 Now for the easy way with pandas

# %% [markdown]
# The hardest part is always getting the data loaded in properly

# %%
# import the data with pandas

data_pd = pd.read_csv('http://scipy-lectures.org/_downloads/populations.txt')

# %%
# what type of thing is this?
type(data_pd)
# Out:
# pandas.DataFrame

# %%
data_pd
# Out:
#      # year\thare\tlynx\tcarrot
# 0        1900\t30e3\t4e3\t48300
# 1    1901\t47.2e3\t6.1e3\t48200
# 2    1902\t70.2e3\t9.8e3\t41500
# 3   1903\t77.4e3\t35.2e3\t38200
# 4   1904\t36.3e3\t59.4e3\t40600
# 5   1905\t20.6e3\t41.7e3\t39800
# 6     1906\t18.1e3\t19e3\t38600
# 7     1907\t21.4e3\t13e3\t42300
# 8      1908\t22e3\t8.3e3\t44500
# 9    1909\t25.4e3\t9.1e3\t42100
# 10   1910\t27.1e3\t7.4e3\t46000
# 11     1911\t40.3e3\t8e3\t46800
# 12    1912\t57e3\t12.3e3\t43800
# 13  1913\t76.6e3\t19.5e3\t40900
# 14  1914\t52.3e3\t45.7e3\t39400
# 15  1915\t19.5e3\t51.1e3\t39000
# 16  1916\t11.2e3\t29.7e3\t36700
# 17   1917\t7.6e3\t15.8e3\t41800
# 18   1918\t14.6e3\t9.7e3\t43300
# 19  1919\t16.2e3\t10.1e3\t41300
# 20   1920\t24.7e3\t8.6e3\t47300

# %% [markdown]
# We need to tell pandas the data is tab-delineated to get rid of the \t

# %%
data_pd = pd.read_csv('http://scipy-lectures.org/_downloads/populations.txt',  sep = '\t')
data_pd
# Out:
#     # year     hare     lynx  carrot
# 0     1900  30000.0   4000.0   48300
# 1     1901  47200.0   6100.0   48200
# 2     1902  70200.0   9800.0   41500
# 3     1903  77400.0  35200.0   38200
# 4     1904  36300.0  59400.0   40600
# 5     1905  20600.0  41700.0   39800
# 6     1906  18100.0  19000.0   38600
# 7     1907  21400.0  13000.0   42300
# 8     1908  22000.0   8300.0   44500
# 9     1909  25400.0   9100.0   42100
# 10    1910  27100.0   7400.0   46000
# 11    1911  40300.0   8000.0   46800
# 12    1912  57000.0  12300.0   43800
# 13    1913  76600.0  19500.0   40900
# 14    1914  52300.0  45700.0   39400
# 15    1915  19500.0  51100.0   39000
# 16    1916  11200.0  29700.0   36700
# 17    1917   7600.0  15800.0   41800
# 18    1918  14600.0   9700.0   43300
# 19    1919  16200.0  10100.0   41300
# 20    1920  24700.0   8600.0   47300

# %% [markdown]
# I want the first column to be the year

# %%
data_pd = pd.read_csv('http://scipy-lectures.org/_downloads/populations.txt', sep = '\t', index_col = '# year')
data_pd

# that worked!
# Out:
#            hare     lynx  carrot
# # year
# 1900    30000.0   4000.0   48300
# 1901    47200.0   6100.0   48200
# 1902    70200.0   9800.0   41500
# 1903    77400.0  35200.0   38200
# 1904    36300.0  59400.0   40600
# 1905    20600.0  41700.0   39800
# 1906    18100.0  19000.0   38600
# 1907    21400.0  13000.0   42300
# 1908    22000.0   8300.0   44500
# 1909    25400.0   9100.0   42100
# 1910    27100.0   7400.0   46000
# 1911    40300.0   8000.0   46800
# 1912    57000.0  12300.0   43800
# 1913    76600.0  19500.0   40900
# 1914    52300.0  45700.0   39400
# 1915    19500.0  51100.0   39000
# 1916    11200.0  29700.0   36700
# 1917     7600.0  15800.0   41800
# 1918    14600.0   9700.0   43300
# 1919    16200.0  10100.0   41300
# 1920    24700.0   8600.0   47300

# %% [markdown]
# Now we are ready to plot

# %%
data_pd.plot()
# Out:
# <Axes: xlabel='# year'>

# %%
data_pd.plot(xlabel = 'Years', ylabel = "Population")

# wow, so easy...
# Out:
# <Axes: xlabel='Years', ylabel='Population'>

# %% [markdown]
# Lots of examples in the docs:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %% [markdown]
# ### In your last exercise, you will upload some data of your choosing and make a scientific plot using the methods you learned today

# %% [markdown]
# # Lab 3.1

# %% [markdown]
# **E.1** Finish Lab 2.2 if you are not done yet

# %% [markdown]
# Congratulations! You finished your first datacamp module

# %% [markdown]
# **E.2** Complete Complete Ch 1-2 of Intermediate Python in datacamp: matplotlib

# %% [markdown]
# This should take you a little while. Don't rush. There is no prize for speed, only a reward for understanding.

# %% [markdown]
# **E.3-5** Go to the matplotlib documentation page (google it). Navigate to the examples gallery. For each of the exercises E.3-E.5, take one sample plot of your choosing, and type it in (don't copy and paste the plotting commands, you need to develop the body memory and think about what the code is doing). For each exercise pick a different type of plot (line, scatter, bar, etc.). **Then modify the plot in 2-3 signifigant ways**, like changing colors, labels, styles, etc. For each change create a new cell to show your work. Explain in words what type of data each kind plot of would be useful for showing.

# %%
#E3
#scatter
import matplotlib.cbook as cbook
price_data = cbook.get_sample_data('goog.npz')['price_data']
price_data = price_data[-250:]
delta1 = np.diff(price_data["adj_close"]) / price_data["adj_close"][:-1]
volume = (15 * price_data["volume"][:-2] / price_data["volume"][0])**2
close = 0.003 * price_data["close"][:-2] / 0.003 * price_data["open"][:-2]

fig, ax = plt.subplots()
ax.scatter(delta1[:-1], delta1[1:])

plt.show()

# %%
#E3
#scatter-change color

fig, ax = plt.subplots()
ax.scatter(delta1[:-1], delta1[1:], c=close, s=volume)

plt.show()

# %%
#E3
#scatter-change opacity, add title, label and grid

fig, ax = plt.subplots()
ax.scatter(delta1[:-1], delta1[1:], c=close, s=volume, alpha=0.5)
ax.set_xlabel(r'$\Delta_i$', fontsize=15)
ax.set_ylabel(r'$\Delta_{i+1}$', fontsize=15)
ax.set_title('Volume and percent change')

ax.grid(True)
fig.tight_layout()

plt.show()

# %% [markdown]
# scatter plot usage:
# ideal when you want to see clusters, outliers, or correlation strength; you're not claiming any smooth relationship between points, just showing how they're distributed

# %%
#E4
#step

x = np.arange(14)
y = np.sin(x / 2)

plt.step(x, y)
plt.plot(x, y)

plt.show()

# %%
#E4
#step-change color and style

plt.step(x, y,)
plt.plot(x, y, 'o--', color='red',)

plt.title('step plot')
plt.show()

# %%
#E4
#step-change opacity and add title and grid

plt.step(x, y,)
plt.plot(x, y, 'o--', color='grey', alpha=0.8)

plt.grid(axis='x', color='0.8')
plt.title('step plot')
plt.show()

# %% [markdown]
# step plot usage: ideal for values that change abruptly and stay constant until the next change (not continuously interpolated).
# for example: interest rate changes over time, inventory stock level, elevator floor over time

# %%
#E5
#stem

x = np.linspace(0.1, 2 * np.pi, 41)
y = np.exp(np.sin(x))

plt.stem(x, y)
plt.show()

# %%
#E5
#stem-change line color and style

markerline = plt.stem(
    x, y, linefmt='grey', markerfmt='D',)

plt.show()

# %%
#E5
#stem-change baseline

markerline, stemlines, baseline = plt.stem(
    x, y, linefmt='grey', markerfmt='D', bottom=1.1)
markerline.set_markerfacecolor('none')

plt.show()

# %% [markdown]
# stem plot usage: great for discrete/individual values where you care about magnitude relative to zero, not trend. for example: digital signal processing, stock daily gains/losses

# %% [markdown]
# ### **E.6** My First Scientific Python Plot
# ### You will present this in class next Wednesday
#
# Find a csv or text file with some scientific data, ideally some data you collected, or someone in your lab collected, or a friend of yours collected. It has to be some real data.
#
# **E.6.1** Upload your data into pandas. Make sure the dataframe is loaded correctly (look at the data).
#
# **E.6.2** Make a table of a subset of the data. (Hint: use my_dataframe[subset_here].table() method)
# Write a table caption that explains what your table is.
#
# **E.6.3** Make a plot of some relevant subset of the data (or all of it, if appropriate), label your axes and write a figure caption
#
# **E.6.4** Do some analysis on your data, like finding the maximum, some basic statistics, etc.. Write some text explaining your methods and your results.

# %%
import pandas as pd

df = pd.read_csv('Dhaka.csv', index_col=0)

print(df.shape)
print(df.dtypes)
df.head()
# Out:
# (23010, 8)
# Station            str
# Year             int64
# Month            int64
# Day              int64
# Rainfall       float64
# Sunshine       float64
# Humidity       float64
# Temperature    float64
# dtype: object
#        Station  Year  Month  Day  Rainfall  Sunshine  Humidity  Temperature
# 153400   Dhaka  1961      1    1       0.5       0.4      80.0         21.5
# 153401   Dhaka  1961      1    2       1.0       5.9      76.0         22.2
# 153402   Dhaka  1961      1    3       0.0       4.2      75.0         23.1
# 153403   Dhaka  1961      1    4       0.0       6.8      74.0         19.8
# 153404   Dhaka  1961      1    5       0.0      10.0      68.0         16.6

# %%
subset = df[df['Year'] == 2020][['Year', 'Month', 'Day', 'Rainfall', 'Sunshine', 'Humidity', 'Temperature']]
subset.head(10)
# Out:
#         Year  Month  Day  Rainfall  Sunshine  Humidity  Temperature
# 174949  2020      1    1       0.0       5.8      70.0         20.1
# 174950  2020      1    2       0.0       3.7      73.0         21.7
# 174951  2020      1    3       2.0       1.4      89.0         18.7
# 174952  2020      1    4      18.0       3.1      84.0         19.2
# 174953  2020      1    5       0.0       1.9      82.0         18.8
# 174954  2020      1    6       0.0       5.8      75.0         16.9
# 174955  2020      1    7       0.0       3.4      88.0         14.3
# 174956  2020      1    8       0.0       5.3      83.0         17.1
# 174957  2020      1    9       0.0       0.3      79.0         18.7
# 174958  2020      1   10       0.0       5.8      77.0         19.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cols = ['Rainfall', 'Sunshine', 'Humidity', 'Temperature']
corr = df[cols].corr()

plt.figure(figsize=(6, 5))
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0, fmt='.2f')
plt.title('Correlation Between Weather Variables', fontweight='bold')
plt.xlabel('Variable', fontweight='bold')
plt.ylabel('Variable', fontweight='bold')
plt.show()

import os 
plt_path = r'E:\One Drive\OneDrive\Desktop'
name = 'presentation.png'
full_path = os.path.join(plt_path, name)
plt.savefig(full_path, dpi=900)

# %%
import pandas as pd
from IPython.display import display

# Variables to analyze
cols = ['Rainfall', 'Sunshine', 'Humidity', 'Temperature']

# 1. Basic statistics
basic_statistics = df[cols].describe()

print("Basic statistics:")
display(basic_statistics)

# 2. Combine Year, Month, and Day into a date column
data = df[cols].copy()
data['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Reshape into columns: Date, Variable, Value
long_data = data.melt(
    id_vars='Date',
    value_vars=cols,
    var_name='Variable',
    value_name='Value'
)

# 3. Select ALL rows matching each variable's minimum
min_values = long_data.groupby('Variable')['Value'].transform('min')

minimum_data = (
    long_data.loc[long_data['Value'] == min_values]
    .sort_values(['Variable', 'Date'])
    .reset_index(drop=True)
)

print("Minimum values and all corresponding dates:")
display(minimum_data)

# 4. Select ALL rows matching each variable's maximum
max_values = long_data.groupby('Variable')['Value'].transform('max')

maximum_data = (
    long_data.loc[long_data['Value'] == max_values]
    .sort_values(['Variable', 'Date'])
    .reset_index(drop=True)
)

print("Maximum values and all corresponding dates:")
display(maximum_data)

# 5. Check for missing data
missing_data = df[cols].isna().sum().to_frame(name='Missing count')
missing_data.index.name = 'Variable'

print("Missing data:")
display(missing_data)
# Out:
# Basic statistics:
#            Rainfall      Sunshine      Humidity   Temperature
# count  23010.000000  23010.000000  23010.000000  23010.000000
# mean       5.507048      6.518466     74.615072     25.835671
# std       15.588238      3.247169     10.973908      4.118754
# min        0.000000      0.000000     29.000000     10.400000
# 25%        0.000000      4.300000     68.000000     22.900000
# 50%        0.000000      7.400000     76.000000     27.200000
# 75%        2.000000      9.100000     83.000000     29.000000
# max      341.000000     13.800000    100.000000     37.800000
# Minimum values and all corresponding dates:
#             Date     Variable  Value
# 0     1975-03-30     Humidity   29.0
# 1     1961-01-03     Rainfall    0.0
# 2     1961-01-04     Rainfall    0.0
# 3     1961-01-05     Rainfall    0.0
# 4     1961-01-06     Rainfall    0.0
# ...          ...          ...    ...
# 16700 2023-09-14     Sunshine    0.0
# 16701 2023-09-20     Sunshine    0.0
# 16702 2023-12-27     Sunshine    0.0
# 16703 2023-12-30     Sunshine    0.0
# 16704 2013-01-09  Temperature   10.4
#
# [16705 rows x 3 columns]
# Maximum values and all corresponding dates:
#         Date     Variable  Value
# 0 1968-02-29     Humidity  100.0
# 1 2004-09-14     Rainfall  341.0
# 2 1996-10-07     Sunshine   13.8
# 3 1968-02-29  Temperature   37.8
# Missing data:
#              Missing count
# Variable
# Rainfall                 0
# Sunshine                 0
# Humidity                 0
# Temperature              0
