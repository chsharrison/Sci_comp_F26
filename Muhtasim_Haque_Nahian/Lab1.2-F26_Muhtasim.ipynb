# %% [markdown]
# put your name, etc here

# %%
Muhtasim Haque Nahian

# %% [markdown]
# # Lecture 1.2

# %% [markdown]
# Wed Aug 24th, 2026
#
# All labs are due Sunday at midnight
#
# Lecture Agenda:
# * debriefing on first class and homework, how's it going?
# * logistics of github, downloading this Lab 1.2 notebook
# * commenting and markup in notebooks
# * workflow for the class

# %% [markdown]
# In general, we will do warmup exercises and lab exercises in a jupyter notebook. For most classes, you will download the notebook from github, open it on your local computer, and then upload your completed work back on github in your folder. Then in the assignment tab in Moodle, submit a url link to the completed lab, along with a screenshot of your completed score for the chapter(s) assigned in datacamp.

# %%
# here is an example of code commenting. The # symbol means everything on this line will be ignored

# %% [markdown]
# Here is an example of markdown text. Because this cell is in markdown mode it will also be ignored by the python shell

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# You created a github account and sent Dr. Harrison your account name in Lab 1.1 to be added to the class github.
#
# Now in our class github site, create a folder for yourself where you will submit your jupyter notebooks. The easiest way to do this is to create a new file that is a placeholder document in the new folder. You can delete it later.

# %% [markdown]
# ## Warmup exercises

# %% [markdown]
# As you are doing these exercises, get familiar with jupyter notebook commands
# https://towardsdatascience.com/jypyter-notebook-shortcuts-bf0101a98330
#
# and markdown text https://medium.com/@ingeh/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed
#
# These exercises are based on what you have learned previously. Feel free to go look at what you did in datacamp to figure out how to answer them.

# %% [markdown]
# **W.1** Define and assign values to three variables of the three types we learned about Monday: integer, floating point, string and boolian.
#
# Note you can add more cells below by pressing the + button above or typing [esc] to command mode, then [b] to enter a cell below, or [a] to enter a cell above. See the link above for more commands

# %%
#integer
a=2
#floating
b=2.2
#string
c="as it was"
#boolian
d=True

# %% [markdown]
# **W.2** Print out the value and check the type of each variable

# %%
print(a)
print(b)
print(c)
print(d)

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# 2
# 2.2
# as it was
# True
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# **W.3** Create a new variable that saves the value of the float variable as a string. Print it out

# %%
f_to_str=str(b)
print(f_to_str)
print(type(f_to_str))
# Out:
# 2.2
# <class 'str'>

# %% [markdown]
# **W.4** Using multiplication of a variable, print out the text "Bueno Bueno Bueno Bueno Bueno" (Shoutout to Monsieur Periné https://youtu.be/JGL-eQAAxGs see 10:45)

# %%
haha="Bueno "
verse_multiply=haha*5
print(verse_multiply)
# Out:
# Bueno Bueno Bueno Bueno Bueno

# %% [markdown]
# **W.5** Do the same thing using addtion

# %%
verse_add=haha+haha+haha+haha+haha
print(verse_add)
# Out:
# Bueno Bueno Bueno Bueno Bueno

# %% [markdown]
# **W.6** If you add an int and a float, what is the resulting variable type? Demonstrate

# %%
#a is an int, b is a float
e=a+b
print(e)
print(type(e))
# Out:
# 4.2
# <class 'float'>

# %% [markdown]
# **W.7** Can you convert a Boolian to an interger type variable? If so, what is the resulting value? What happens if you convert a float to an int?

# %%
#d is a boolian. converting it to an int

bool_to_int=int(d)
print(bool_to_int)
print(type(bool_to_int))

#b=2.2 is a float. converting it to an int

f_to_int=int(b)
print(f_to_int)
print(type(f_to_int))
# Out:
# 1
# <class 'int'>
# 2
# <class 'int'>

# %% [markdown]
# so when i converted the bool to an int, it was converted to an integer.
# and in case of float to an int, since i didnt specify the rounding, it rounded to the nearest int 2.

# %% [markdown]
# # Lab 1.2

# %% [markdown]
# ## Lab Exercises

# %% [markdown]
# **E.1** Complete Ch 2 of Introduction to Python in datacamp.

# %% [markdown]
# **E.2** Below you will spend time practicing what you have learned in Ch 2. Use a comination of code, code commenting, and markdown text to take notes. Make sure you investigate how python syntax works and understand what you are doing, and what went wrong if you have any issues. You can refer to this document later if you need to review, so give future you lots of commenting to be helpful.

# %% [markdown]
# **E.2.1** Let's work on lists, indexing and printing out elements of lists.
#
# We are going to calculate the BMI of five family members (or friends/colleaues if you have a small family, or famous people/politicians/atheletes if you really don't like talking to people, they just have to be adults and you need their data). Make intellegently named lists for the first name, last name, height, weight and age of each person. So, five lists in total.

# %% [markdown]
# I have primarily used Wikipedia to get the information on the height, weight, and date of birth of five popular figures. Here are the reference links for the sources:
# 1. LeBron James (age 41, 2.06m, 113kg) (https://en.wikipedia.org/wiki/LeBron_James)
# 2. Cristiano Ronaldo (age 41, 1.87m, 84kg) (https://en.wikipedia.org/wiki/Cristiano_Ronaldo)
# 3. Dwayne Johnson (age 54, 1.96m, 118kg) (https://en.wikipedia.org/wiki/Dwayne_Johnson)
# 4. Lionel Messi (age 39, 1.70m, 67kg) (https://en.wikipedia.org/wiki/Lionel_Messi)
# 5. Elon Musk (age 55, 1.88m, 85kg (https://en.wikipedia.org/wiki/Elon_Musk)

# %%
first_name=["LeBron", "Cristiano", "Dwayne", "Lionel", "Elon"]
last_name=["James", "Ronaldo", "Johnson", "Messi", "Musk"]
height_m=[2.06, 1.87, 1.96, 1.70, 1.88]
weight_kg=[113, 84, 118, 67, 85]
age_yrs=[41, 41, 54, 39, 55]

print(first_name)
print(last_name)
print(height_m)
print(weight_kg)
print(age_yrs)
# Out:
# ['LeBron', 'Cristiano', 'Dwayne', 'Lionel', 'Elon']
# ['James', 'Ronaldo', 'Johnson', 'Messi', 'Musk']
# [2.06, 1.87, 1.96, 1.7, 1.88]
# [113, 84, 118, 67, 85]
# [41, 41, 54, 39, 55]

# %% [markdown]
# **E.2.2** Now create a new list that calculates the BMI of each person using the lists you created before

# %%
# bmi=weight(kg)/height(m)^2
bmi=[round(weight_kg[0]/(height_m[0]**2),1), round(weight_kg[1]/(height_m[1]**2),1), round(weight_kg[2]/(height_m[2]**2),1), round(weight_kg[3]/(height_m[3]**2),1), round(weight_kg[4]/(height_m[4]**2),1)]

print(bmi)
# Out:
# [26.6, 24.0, 30.7, 23.2, 24.0]

# %% [markdown]
# **E.2.3** Look up the weight classification of each person based on their BMI (what's a good source for this, who do you trust?). Create a new list with this information for each person. (Don't judge, we live in Louisiana, which is not known for healthfood.)

# %% [markdown]
# I have used the BMI category from https://www.cdc.gov/bmi/adult-calculator/bmi-categories.html
#
# ![image.png](attachment:d888860f-37fa-4ad3-923a-23c545c84868.png)

# %%
bmi_cat=["overweight", "healthy", "obese", "healthy", "healthy"]
print(bmi_cat)
# Out:
# ['overweight', 'healthy', 'obese', 'healthy', 'healthy']

# %% [markdown]
# **E.2.3** Let's practice some print statements and iterate manually through the people on your lists.
#
# For each person, print out something like: "First_name last_name, age xx, has a height of xx units and weight of xx units, giving them a body mass index (BMI) of xx, making them yy" where yy is if they are normal, obese, etc.

# %%
print(first_name[0], last_name[0], ", age", age_yrs[0], "has a height of", height_m[0], "meters and weight of", weight_kg[0], "kg, giving them a body mass index (BMI) of", bmi[0], ", making them", bmi_cat[0])
print(first_name[1], last_name[1], ", age", age_yrs[1], "has a height of", height_m[1], "meters and weight of", weight_kg[1], "kg, giving them a body mass index (BMI) of", bmi[1], ", making them", bmi_cat[1])
print(first_name[2], last_name[2], ", age", age_yrs[2], "has a height of", height_m[2], "meters and weight of", weight_kg[2], "kg, giving them a body mass index (BMI) of", bmi[2], ", making them", bmi_cat[2])
print(first_name[3], last_name[3], ", age", age_yrs[3], "has a height of", height_m[3], "meters and weight of", weight_kg[3], "kg, giving them a body mass index (BMI) of", bmi[3], ", making them", bmi_cat[3])
print(first_name[4], last_name[4], ", age", age_yrs[4], "has a height of", height_m[4], "meters and weight of", weight_kg[4], "kg, giving them a body mass index (BMI) of", bmi[4], ", making them", bmi_cat[4])
# Out:
# LeBron James , age 41 has a height of 2.06 meters and weight of 113 kg, giving them a body mass index (BMI) of 26.6 , making them overweight
# Cristiano Ronaldo , age 41 has a height of 1.87 meters and weight of 84 kg, giving them a body mass index (BMI) of 24.0 , making them healthy
# Dwayne Johnson , age 54 has a height of 1.96 meters and weight of 118 kg, giving them a body mass index (BMI) of 30.7 , making them obese
# Lionel Messi , age 39 has a height of 1.7 meters and weight of 67 kg, giving them a body mass index (BMI) of 23.2 , making them healthy
# Elon Musk , age 55 has a height of 1.88 meters and weight of 85 kg, giving them a body mass index (BMI) of 24.0 , making them healthy

# %% [markdown]
# **E.2.4** Now add/append your information to each of the lists, and do the same print statement for you. Make a resolution to eat more veggies.

# %%
first_name1 = first_name + ["Muhtasim Haque"]
last_name1 = last_name + ["Nahian"]
age_yrs1 = age_yrs + [25]
height_m1 = height_m + [1.7]
weight_kg1 = weight_kg +[97]

# %%
bmi1 = bmi + [round(weight_kg1[5]/(height_m1[5]**2),1)]

# %%
print(first_name1)
print(last_name1)
print(height_m1)
print(weight_kg1)
print(age_yrs1)
print(bmi1)
# Out:
# ['LeBron', 'Cristiano', 'Dwayne', 'Lionel', 'Elon', 'Muhtasim Haque']
# ['James', 'Ronaldo', 'Johnson', 'Messi', 'Musk', 'Nahian']
# [2.06, 1.87, 1.96, 1.7, 1.88, 1.7]
# [113, 84, 118, 67, 85, 97]
# [41, 41, 54, 39, 55, 25]
# [26.6, 24.0, 30.7, 23.2, 24.0, 33.6]

# %%
bmi_cat1 = bmi_cat + ["obese"]
print(bmi_cat1)
# Out:
# ['overweight', 'healthy', 'obese', 'healthy', 'healthy', 'obese']

# %%
print(first_name1[5], last_name1[5], ", age", age_yrs1[5], "has a height of", height_m1[5], "meters and weight of", weight_kg1[5], "kg, giving them a body mass index (BMI) of", bmi1[5], ", making them", bmi_cat1[5], ". It is high time he started dieting and definitely included veggies in his diet.")
# Out:
# Muhtasim Haque Nahian , age 25 has a height of 1.7 meters and weight of 97 kg, giving them a body mass index (BMI) of 33.6 , making them obese . It is high time he started dieting and definitely included veggies in his diet.

# %% [markdown]
# When you are done with your lab, upload this document to your github folder on the class site. Then submit a url link to the completed lab, along with a screenshot of your completed Ch 2 score in datacamp, to the assignment tab in Moodle.

# %% [markdown]
# # Scratch

# %%
# this is an area of the notebook you can mess around and test things out, if you don't want to put it above
